# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# # ERA5

# %%
era5 = gpd.read_file(r"C:\Users\Tommy\Desktop\IGS_sh\era5.shp")
africa = gpd.read_file(r"C:\Users\Tommy\Documents\GIS_Data\africa\afr_g2014_2013_0.shp")

# %%
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))
fig.suptitle("Standard Deviation(STD)", fontsize=16)

# Plot the 'afplot' in all subplots
afplot1 = africa.plot(ax=axes[0, 0], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot1.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot1.get_yticklabels()]

# Set the new labels
afplot1.set_xlabel('Longitude')
afplot1.set_ylabel('Latitude')
afplot1.set_xticklabels(x_labels)
afplot1.set_yticklabels(y_labels)


afplot2 = africa.plot(ax=axes[0, 1], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot2.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot2.get_yticklabels()]

# Set the new labels
afplot2.set_xlabel('Longitude')
# afplot2.set_ylabel('Latitude')
afplot2.set_xticklabels(x_labels)
# afplot2.set_yticks([])
afplot2.set_yticklabels(y_labels)


afplot3 = africa.plot(ax=axes[1, 0], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot3.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot3.get_yticklabels()]

# Set the new labels
afplot3.set_xlabel('Longitude')
afplot3.set_ylabel('Latitude')
afplot3.set_xticklabels(x_labels)
afplot3.set_yticklabels(y_labels)


afplot4 = africa.plot(ax=axes[1, 1], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot4.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot4.get_yticklabels()]

# Set the new labels
afplot4.set_xlabel('Longitude')
# afplot4.set_ylabel('Latitude')
afplot4.set_xticklabels(x_labels)
# afplot4.set_yticks([])
afplot4.set_yticklabels(y_labels)

['stdDevIGS', 'stdDeNGL', 'stdDevVMF3', 'stdDevERA5']

# Plot 'era5' data for different columns in the subplots
era5.plot(ax=afplot1, marker='o', markersize=20, column='stdDevIGS', cmap="viridis", legend=True, legend_kwds={'label': 'STD(mm)', 'shrink': 0.5})
era5.plot(ax=afplot2, marker='o', markersize=20, column='stdDeNGL', cmap="viridis", legend=True, legend_kwds={'label': 'STD(mm)', 'shrink': 0.5})
era5.plot(ax=afplot3, marker='o', markersize=20, column='stdDevVMF3', cmap="viridis", legend=True, legend_kwds={'label': 'STD(mm)', 'shrink': 0.5})
era5.plot(ax=afplot4, marker='o', markersize=20, column='stdDevERA5', cmap="viridis", legend=True, legend_kwds={'label': 'STD(mm)', 'shrink': 0.5})

# Set titles for the subplots
axes[0, 0].set_title('IGS')
axes[0, 1].set_title('NGL')
axes[1, 0].set_title('VMF3')
axes[1, 1].set_title('ERA5')

plt.tight_layout()
# plt.show()
plt.savefig(r".\stdev\StdDev-ERA5.jpeg", dpi=150)
# Out:
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\3008208621.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot1.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\3008208621.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot1.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\3008208621.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot2.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\3008208621.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot2.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\3008208621.py:39: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot3.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\3008208621.py:40: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot3.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\3008208621.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot4.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\3008208621.py:53: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot4.set_yticklabels(y_labels)

# %% [markdown]
# # Gtrop

# %%
gtrop = gpd.read_file(r"C:\Users\Tommy\Desktop\IGS_sh\gtrop.shp")
# africa = gpd.read_file(r"C:\Users\Tommy\Documents\GIS_Data\africa\afr_g2014_2013_0.shp")

# %%
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))
fig.suptitle("Standard Deviation(STD)", fontsize=16)

# Plot the 'afplot' in all subplots
afplot1 = africa.plot(ax=axes[0, 0], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot1.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot1.get_yticklabels()]

# Set the new labels
afplot1.set_xlabel('Longitude')
afplot1.set_ylabel('Latitude')
afplot1.set_xticklabels(x_labels)
afplot1.set_yticklabels(y_labels)


afplot2 = africa.plot(ax=axes[0, 1], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot2.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot2.get_yticklabels()]

# Set the new labels
afplot2.set_xlabel('Longitude')
# afplot2.set_ylabel('Latitude')
afplot2.set_xticklabels(x_labels)
# afplot2.set_yticks([])
afplot2.set_yticklabels(y_labels)


afplot3 = africa.plot(ax=axes[1, 0], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot3.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot3.get_yticklabels()]

# Set the new labels
afplot3.set_xlabel('Longitude')
afplot3.set_ylabel('Latitude')
afplot3.set_xticklabels(x_labels)
afplot3.set_yticklabels(y_labels)


afplot4 = africa.plot(ax=axes[1, 1], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot4.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot4.get_yticklabels()]

# Set the new labels
afplot4.set_xlabel('Longitude')
# afplot4.set_ylabel('Latitude')
afplot4.set_xticklabels(x_labels)
# afplot4.set_yticks([])
afplot4.set_yticklabels(y_labels)

['stdDevIGS', 'stdDeNGL', 'stdDevVMF3', 'stdDevERA5']

# Plot 'era5' data for different columns in the subplots
gtrop.plot(ax=afplot1, marker='o', markersize=20, column='stdDevIGS', cmap="viridis", legend=True, legend_kwds={'label': 'STD(mm)', 'shrink': 0.5})
gtrop.plot(ax=afplot2, marker='o', markersize=20, column='stdDeNGL', cmap="viridis", legend=True, legend_kwds={'label': 'STD(mm)', 'shrink': 0.5})
gtrop.plot(ax=afplot3, marker='o', markersize=20, column='stdDevVMF3', cmap="viridis", legend=True, legend_kwds={'label': 'STD(mm)', 'shrink': 0.5})
gtrop.plot(ax=afplot4, marker='o', markersize=20, column='stdDevERA5', cmap="viridis", legend=True, legend_kwds={'label': 'STD(mm)', 'shrink': 0.5})

# Set titles for the subplots
axes[0, 0].set_title('IGS')
axes[0, 1].set_title('NGL')
axes[1, 0].set_title('VMF3')
axes[1, 1].set_title('ERA5')

plt.tight_layout()
# plt.show()
plt.savefig(r".\stdev\StdDev-Gtrop.jpeg", dpi=150)
# Out:
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\1164173754.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot1.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\1164173754.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot1.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\1164173754.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot2.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\1164173754.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot2.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\1164173754.py:39: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot3.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\1164173754.py:40: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot3.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\1164173754.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot4.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14260\1164173754.py:53: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot4.set_yticklabels(y_labels)
