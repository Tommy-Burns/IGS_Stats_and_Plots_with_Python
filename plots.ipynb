# %%
import geopandas as gpd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
era5 = gpd.read_file(r"C:\Users\Tommy\Desktop\IGS_sh\era5.shp")
africa = gpd.read_file(r"C:\Users\Tommy\Documents\GIS_Data\africa\afr_g2014_2013_0.shp")

# print(era5.columns)

# %%
mean_cols = ['Mean_IGS', 'Mean_NGL', 'Mean_VMF3', 'Mean_ERA5']
afplot = africa.plot(figsize=(8, 8), color='gray', alpha=0.5)
era5.plot(ax=afplot, marker='o', markersize=80, column='Mean_IGS', cmap="inferno", legend=True, legend_kwds={'orientation': 'horizontal'})

# %%
mean_cols = ['Mean_IGS', 'Mean_NGL', 'Mean_VMF3', 'Mean_ERA5']


# Create a 2x2 grid of subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))
fig.suptitle("Mean PWV", fontsize=16)

# Plot the 'afplot' in all subplots
afplot1 = africa.plot(ax=axes[0, 0], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot1.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot1.get_yticklabels()]

# Set the new labels
afplot1.set_xlabel('Longitude')
afplot1.set_ylabel('Latitude')
afplot1.set_xticklabels(x_labels)
afplot1.set_yticklabels(y_labels)


afplot2 = africa.plot(ax=axes[0, 1], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot2.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot2.get_yticklabels()]

# Set the new labels
afplot2.set_xlabel('Longitude')
# afplot2.set_ylabel('Latitude')
afplot2.set_xticklabels(x_labels)
# afplot2.set_yticks([])
afplot2.set_yticklabels(y_labels)


afplot3 = africa.plot(ax=axes[1, 0], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot3.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot3.get_yticklabels()]

# Set the new labels
afplot3.set_xlabel('Longitude')
afplot3.set_ylabel('Latitude')
afplot3.set_xticklabels(x_labels)
afplot3.set_yticklabels(y_labels)


afplot4 = africa.plot(ax=axes[1, 1], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot4.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot4.get_yticklabels()]

# Set the new labels
afplot4.set_xlabel('Longitude')
# afplot4.set_ylabel('Latitude')
afplot4.set_xticklabels(x_labels)
# afplot4.set_yticks([])
afplot4.set_yticklabels(y_labels)



# Plot 'era5' data for different columns in the subplots
era5.plot(ax=afplot1, marker='o', markersize=20, column='Mean_IGS', cmap="viridis", legend=True, legend_kwds={'label': 'PWV(mm)', 'shrink': 0.5})
era5.plot(ax=afplot2, marker='o', markersize=20, column='Mean_NGL', cmap="viridis", legend=True, legend_kwds={'label': 'PWV(mm)', 'shrink': 0.5})
era5.plot(ax=afplot3, marker='o', markersize=20, column='Mean_VMF3', cmap="viridis", legend=True, legend_kwds={'label': 'PWV(mm)', 'shrink': 0.5})
era5.plot(ax=afplot4, marker='o', markersize=20, column='Mean_ERA5', cmap="viridis", legend=True, legend_kwds={'label': 'PWV(mm)', 'shrink': 0.5})

# Set titles for the subplots
axes[0, 0].set_title('IGS')
axes[0, 1].set_title('NGL')
axes[1, 0].set_title('VMF3')
axes[1, 1].set_title('ERA5')

plt.tight_layout()
# plt.show()
plt.savefig(r".\mean\Mean_PWV_Values-ERA5.jpeg", dpi=150)
# Out:
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\2170090073.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot1.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\2170090073.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot1.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\2170090073.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot2.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\2170090073.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot2.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\2170090073.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot3.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\2170090073.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot3.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\2170090073.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot4.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\2170090073.py:56: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot4.set_yticklabels(y_labels)

# %%
mean_bias_cols = ['MB(IGSvsERA5)', 'MB(NGLvsERA5)', 'MB(VMF3vsERA5)', 'MB(VMF3vsIGS)','MB(VMF3vsNGL)', 'MB(IGSvsNGL)']

# 'stdDevVMF3', 'stdDevERA5', 'MB(IGSvsER', 'MAE(IGSvsE', 'RMSE(IGSvs',
#        'MB(NGLvsER', 'MAE(NGLvsE', 'RMSE(NGLvs', 'MB(VMF3vsE', 'MAE(VMF3vs',
#        'RMSE(VMF3v', 'MB(VMF3vsI', 'MAE(VMF3_1', 'RMSE(VMF_1', 'MB(VMF3vsN',


# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
fig.suptitle("Mean Bias", fontsize=16)

# Plot the 'afplot' in all subplots
afplot1 = africa.plot(ax=axes[0, 0], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot1.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot1.get_yticklabels()]

# Set the new labels
afplot1.set_xlabel('Longitude')
afplot1.set_ylabel('Latitude')
afplot1.set_xticklabels(x_labels)
afplot1.set_yticklabels(y_labels)

afplot2 = africa.plot(ax=axes[0, 1], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot2.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot2.get_yticklabels()]

# Set the new labels
afplot2.set_xlabel('Longitude')
# afplot2.set_ylabel('Latitude')
afplot2.set_xticklabels(x_labels)
# afplot2.set_yticks([])
afplot2.set_yticklabels(y_labels)

afplot3 = africa.plot(ax=axes[0, 2], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot3.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot3.get_yticklabels()]

# Set the new labels
afplot3.set_xlabel('Longitude')
# afplot3.set_ylabel('Latitude')
afplot3.set_xticklabels(x_labels)
# afplot3.set_yticks([])
afplot3.set_yticklabels(y_labels)

afplot4 = africa.plot(ax=axes[1, 0], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot4.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot4.get_yticklabels()]

# Set the new labels
afplot4.set_xlabel('Longitude')
afplot4.set_ylabel('Latitude')
afplot4.set_xticklabels(x_labels)
afplot4.set_yticklabels(y_labels)

afplot5 = africa.plot(ax=axes[1, 1], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot5.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot5.get_yticklabels()]

# Set the new labels
afplot5.set_xlabel('Longitude')
# afplot5.set_ylabel('Latitude')
afplot5.set_xticklabels(x_labels)
# afplot5.set_yticks([])
afplot5.set_yticklabels(y_labels)

afplot6 = africa.plot(ax=axes[1, 2], color='gray', alpha=0.5)
# Get the current labels
x_labels = [item.get_text().replace('−', '-')+'°E' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°W' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot6.get_xticklabels()]
y_labels = [item.get_text().replace('−', '-')+'°N' if float(item.get_text().replace('−', '-'))>0 else item.get_text().replace('−', '-')[1:]+'°S' if float(item.get_text().replace('−', '-'))<0 else '0°' for item in afplot6.get_yticklabels()]

# Set the new labels
afplot6.set_xlabel('Longitude')
# afplot6.set_ylabel('Latitude')
afplot6.set_xticklabels(x_labels)
# afplot6.set_yticks([])
afplot6.set_yticklabels(y_labels)

# Plot 'era5' data for different columns in the subplots
era5.plot(ax=afplot1, marker='o', markersize=20, column='MB(IGSvsER', cmap="viridis", legend=True, legend_kwds={'label': 'Mean Bias(mm)', 'shrink': 0.5})
era5.plot(ax=afplot2, marker='o', markersize=20, column='MB(NGLvsER', cmap="viridis", legend=True, legend_kwds={'label': 'Mean Bias(mm)', 'shrink': 0.5})
era5.plot(ax=afplot3, marker='o', markersize=20, column='MB(VMF3vsE', cmap="viridis", legend=True, legend_kwds={'label': 'Mean Bias(mm)', 'shrink': 0.5})
era5.plot(ax=afplot4, marker='o', markersize=20, column='MB(VMF3vsI', cmap="viridis", legend=True, legend_kwds={'label': 'Mean Bias(mm)', 'shrink': 0.5})
era5.plot(ax=afplot5, marker='o', markersize=20, column='MB(VMF3vsN', cmap="viridis", legend=True, legend_kwds={'label': 'Mean Bias(mm)', 'shrink': 0.5})
era5.plot(ax=afplot6, marker='o', markersize=20, column='MB(IGSvsNG', cmap="viridis", legend=True, legend_kwds={'label': 'Mean Bias(mm)', 'shrink': 0.5})

# Set titles for the subplots
axes[0, 0].set_title('IGSvsERA5')
axes[0, 1].set_title('NGLvsERA5')
axes[0, 2].set_title('VMF3vsERA5')
axes[1, 0].set_title('VMF3vsIGS')
axes[1, 1].set_title('VMF3vsNGL')
axes[1, 2].set_title('IGSvsNGL')

plt.tight_layout()
plt.savefig(r".\mean_bias\Mean_Bias_Values-ERA5.jpeg", dpi=150)
# Out:
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot1.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot1.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot2.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot2.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:44: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot3.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:46: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot3.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:56: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot4.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:57: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot4.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot5.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:69: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot5.set_yticklabels(y_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:79: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot6.set_xticklabels(x_labels)
# C:\Users\Tommy\AppData\Local\Temp\ipykernel_14088\3881975520.py:81: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   afplot6.set_yticklabels(y_labels)

# %%
# Create a KDE plot
sns.set(style='white')
sns.kdeplot(era5['Mean_IGS'], shade=True)


plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Kernel Density Estimation (KDE) Plot")
plt.show()
